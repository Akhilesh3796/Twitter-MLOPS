# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhilesh3796/Twitter-MLOPS/blob/Twitter-1.0/Twitter_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy
# !pip install textblob
# !pip install flask
# !pip install flask-bootstrap

# %%
def get_tweet_sentiment(tweet):
    # Create a TextBlob object of the tweet text
    blob = TextBlob(tweet)
    # Get the polarity of the TextBlob object (-1 to 1)
    polarity = blob.sentiment.polarity
    # Classify the tweet as happy, sad, or neutral based on polarity
    if polarity > 0:
        return 'happy'
    elif polarity < 0:
        return 'sad'
    else:
        return 'neutral'

# Define a list of Twitter usernames to analyze
usernames = ['bbcworld']

# Analyze the sentiment of the latest 100 tweets of each user and print the result
for username in usernames:
    tweets = api.user_timeline(screen_name=username, count=100)
    for tweet in tweets:
        sentiment = get_tweet_sentiment(tweet.text)
        print(username, tweet.text, sentiment)

# %%
# !pip install vaderSentiment
import tweepy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer


# Set up Tweepy API connection
consumer_key = '5TDSE4D0bvOGRLsAGQjRTFdxa'
consumer_secret = 'xw5Ll6WLEp9ptRNPprIWE8n2jqEiO21h71CEQYWDYpWzNdu1kN'
access_token = '265195902-mSPaW59D6ZwGlZQDo9oS8EsGJGvXSG5GIf8pqghZ'
access_token_secret = '7JGPgjJe4XBN7v5iRXBf1kOu9CA1PWvD3JHrMV1QD7bme'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# Initialize VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Define a function to get the sentiment of a tweet
def get_tweet_sentiment(tweet):
    # Use VADER sentiment analyzer on the tweet text
    sentiment = analyzer.polarity_scores(tweet)
    # Classify the tweet as happy, sad, or neutral based on the compound score
    if sentiment['compound'] > 0.05:
        return 'happy'
    elif sentiment['compound'] < -0.05:
        return 'sad'
    else:
        return 'neutral'

# Define a list of Twitter usernames to analyze
usernames = ['bbcworld']

# Analyze the sentiment of the latest 100 tweets of each user and print the result
for username in usernames:
    tweets = api.user_timeline(screen_name=username, count=100)
    for tweet in tweets:
        sentiment = get_tweet_sentiment(tweet.text)
        print(username, tweet.text, sentiment)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# bbcworld Mexican Ambassador to attend St Piran's Day parade https://t.co/UdowKhfCdP neutral
# bbcworld Six reasons Alex Murdaugh's legal woes are far from over https://t.co/XfyNbVyeTy sad
# bbcworld Street fighting in Bakhmut but Russia not in control - deputy mayor https://t.co/2Sg4EYCFm7 sad
# bbcworld 'Trump or bust' - grassroots Republicans still loyal https://t.co/2vVwC4kyy5 happy
# bbcworld At least 17 dead in Jakarta fuel storage depot fire https://t.co/55mkjip330 sad
# bbcworld What's the least exercise we can get away with? https://t.co/8s3L222Kmy neutral
# bbcworld Emmanuel Macron's mission to counter Russia in Africa https://t.co/2I3uMLz0el neutral
# bbcworld Why Alex Murdaugh was spared the death penalty https://t.co/s6fRQZl8lA sad
# bbcworld Bakhmut attacks still being repelled, says Ukraine https://t.co/TZtjQPmL31 sad
# ...
